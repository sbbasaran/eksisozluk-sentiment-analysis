# %%
import pandas as pd

# %%
belediye = pd.read_csv("")
kadıköy = pd.read_csv("")
kadıköymahalle1 = pd.read_csv("")
kadıköymahalle2 = pd.read_csv("")

# %%
belediye = belediye.dropna().reset_index(drop=True)
kadıköygenel = kadıköygenel.dropna().reset_index(drop=True)
kadıköymahalle1 = kadıköymahalle1.dropna().reset_index(drop=True)
kadıköymahalle2 = kadıköymahalle2.dropna().reset_index(drop=True)

# %%
belediye.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2509 entries, 0 to 2508
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Entry       2509 non-null   object
#  1   Author      2509 non-null   object
#  2   Date        2509 non-null   object
#  3   Old_Topic   2509 non-null   object
#  4   New_Topic   2509 non-null   object
#  5   Edited      2509 non-null   bool
#  6   Entry_Date  2509 non-null   object
#  7   Edit_Date   445 non-null    object
# dtypes: bool(1), object(7)
# memory usage: 139.8+ KB

# %%
kadıköy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Entry       6867 non-null   object
#  1   Author      6867 non-null   object
#  2   Date        6867 non-null   object
#  3   Old_Topic   6867 non-null   object
#  4   New_Topic   6867 non-null   object
#  5   Edited      6867 non-null   bool
#  6   Entry_Date  6867 non-null   object
#  7   Edit_Date   1122 non-null   object
# dtypes: bool(1), object(7)
# memory usage: 382.4+ KB

# %%
kadıköymahalle1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8346 entries, 0 to 8345
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Entry       8346 non-null   object
#  1   Author      8346 non-null   object
#  2   Date        8346 non-null   object
#  3   Old_Topic   8346 non-null   object
#  4   New_Topic   8346 non-null   object
#  5   Edited      8346 non-null   bool
#  6   Entry_Date  8346 non-null   object
#  7   Edit_Date   1574 non-null   object
# dtypes: bool(1), object(7)
# memory usage: 464.7+ KB

# %%
kadıköymahalle2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Entry       2520 non-null   object
#  1   Author      2520 non-null   object
#  2   Date        2520 non-null   object
#  3   Old_Topic   2520 non-null   object
#  4   New_Topic   2520 non-null   object
#  5   Edited      2520 non-null   bool
#  6   Entry_Date  2520 non-null   object
#  7   Edit_Date   479 non-null    object
# dtypes: bool(1), object(7)
# memory usage: 140.4+ KB

# %%
mahalle_df = pd.concat([kadıköymahalle1,kadıköymahalle2])
## df = pd.concat([belediye, kadıköygenel, kadıköymahalle2,kadıköymahalle1])

# %%
mahalle_df.to_csv("df_mahallekadıköy.csv", index=False)

# %%
mahalle_df
# Out:
#                                                   Entry  \
# 0     gerçekten hayran olduğum bir ilçe ???? uzun uğ...
# 1     zombi istilasında kurtarılmış bölge hissiyatı ...
# 2               aslında ilçe olmayan bir kadıköy semti.
# 3     eskiden kafa dinlemek için gittiğimiz şimdi ka...
# 4     umut sarıkaya'nın, üzeri sepet gibi orgulu yaz...
# ...                                                 ...
# 2515  türkiye istanbul ankara izmir gibi saçma sapan...
# 2516  bostancı'nın nesi var amk!!\n\nbana sorarsanız...
# 2517  göztepe ve caddebostan'ı da dahil ederek söylü...
# 2518  çocukluğum, ergenliğim, gençliğim. kısacası tü...
# 2519  istanbul'da mülteci veya turist istilasına uğr...
#
#                        Author                      Date  \
# 0            megaloman despot          02.09.2022 03:20
# 1                 tatardoktor          02.09.2022 03:23
# 2             gottacatchemall          02.09.2022 05:00
# 3           planescapetorment          02.09.2022 05:24
# ...

# %%
kadıköygenel
# Out:
#                                                   Entry  \
# 0     son zamanlarda olan durumdur. kadıköy'de yaşay...
# 1     beyoğlu'nun batıp kadıköy'ün yükselişiyle gözl...
# 2     metronun açılması ve ulaşımın kolay olması ned...
# 3     (bkz: işte bunlar hep kentsel dönüşüm)\n\ninşa...
# 4     once moda sahilinde içtiği bira sisesini kırıp...
# ...                                                 ...
# 6862  yarın tekrar kucağına sığınacağım kadıköydür e...
# 6863  son günlerde her akşam yaptığım eylem. artık y...
# 6864  seviyorum. insanlar cok liberal hatta abartı d...
# 6865  her hafta olmasa da ara ara yapmak istediğim e...
# 6866  kadıköy değilde yakın bir yerlerinde, yeni yen...
#
#                         Author              Date  \
# 0                  door creaks  13.10.2016 15:28
# 1                 arda selanik  13.10.2016 15:34
# 2                    kartalrck  13.10.2016 15:39
# 3             orantisizempatik  13.10.2016 15:48
# ...

# %%
belediye
# Out:
#                                                   Entry  \
# 0     arife gunu yarim gun mesaisini yapmami$, tembe...
# 1     sorumluluklarin %50sini yerine getirse, kadiko...
# 2     sağa sola kent yaşamının gerçek sahibi yayalar...
# 3                      (bkz: kadikoy afet kriz merkezi)
# 4     internet sitesinde sahipsiz kedi ve köpekler i...
# ...                                                 ...
# 2504                      ama yol yaptı. belediye değil
# 2505  durun ya bu şey değil mi? deri pantolonlu, eld...
# 2506  telefonla konuşarak araç sür ya da far yakma, ...
# 2507  üst edit: adam troll çıktı rıza baba.\n\n2 yol...
# 2508     belediyeler çalışıyor,kudurun orospu çocukları
#
#                            Author                      Date  \
# 0                             ssg  21.02.2002 12:03 ~ 12:03
# 1                        deadpoem          11.01.2003 16:24
# 2                   melancholyman  01.02.2003 02:10 ~ 02:12
# ...

# %%
kadıkoy_df = pd.concat([belediye, kadıköygenel, mahalle_df])

# %%
kadıköy_df
# Out:
#                                                   Entry  \
# 0     arife gunu yarim gun mesaisini yapmami$, tembe...
# 1     sorumluluklarin %50sini yerine getirse, kadiko...
# 2     sağa sola kent yaşamının gerçek sahibi yayalar...
# 3                      (bkz: kadikoy afet kriz merkezi)
# 4     internet sitesinde sahipsiz kedi ve köpekler i...
# ...                                                 ...
# 2515  türkiye istanbul ankara izmir gibi saçma sapan...
# 2516  bostancı'nın nesi var amk!!\n\nbana sorarsanız...
# 2517  göztepe ve caddebostan'ı da dahil ederek söylü...
# 2518  çocukluğum, ergenliğim, gençliğim. kısacası tü...
# 2519  istanbul'da mülteci veya turist istilasına uğr...
#
#                        Author                      Date  \
# 0                         ssg  21.02.2002 12:03 ~ 12:03
# 1                    deadpoem          11.01.2003 16:24
# 2               melancholyman  01.02.2003 02:10 ~ 02:12
# 3                      mercan          21.03.2003 18:46
# ...

# %%
kadıkoy_df.to_csv("kadıkoy_df.csv", index=False)
